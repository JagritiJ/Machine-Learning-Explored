# %% [markdown]
# <h1> First Notebook</h1>
# # First Notebook
#
# Markdown
# # for Headings
# **bold** *italics*
# - List 1
# - List 2
#
#
# # Frame
# - Descriptive
# - Inferential
# - Predictive
# - Casual
#
# # Acquire
# - Flat File - csv
# - DataBase
# - WebPage
# - API
#
# # Refine
# - Convert
# - Parse
# - Add

# %%
x=9

# %%
y=3

# %%
x+y
# Out:
# 12

# %% [markdown]
# # Peeling the Onion
#
# ## Frame
# - what is the trend of prices across different markets and years
#
# ## Acquire
# - NHRDF database getting the database (see Acquire for more information)
#
# ## Refine

# %%
import numpy as np
import pandas as pd

# %%
# !pwd
# Out:
# /Users/jagritij/art-data-science/notebook

# %%
df_raw = pd.read_csv("onion/MonthWiseMarketArrivals.csv")

# %%
df_raw.head()
# Out:
#        market    month  year  quantity priceMin priceMax priceMod
# 0  ABOHAR(PB)  January  2005      2350      404      493      446
# 1  ABOHAR(PB)  January  2006       900      487      638      563
# 2  ABOHAR(PB)  January  2010       790     1283     1592     1460
# 3  ABOHAR(PB)  January  2011       245     3067     3750     3433
# 4  ABOHAR(PB)  January  2012      1035      523      686      605

# %%
df_raw.head()
# Out:
#        market    month  year  quantity priceMin priceMax priceMod
# 0  ABOHAR(PB)  January  2005      2350      404      493      446
# 1  ABOHAR(PB)  January  2006       900      487      638      563
# 2  ABOHAR(PB)  January  2010       790     1283     1592     1460
# 3  ABOHAR(PB)  January  2011       245     3067     3750     3433
# 4  ABOHAR(PB)  January  2012      1035      523      686      605

# %%
df_raw.tail()
# Out:
#           market     month   year   quantity  priceMin   priceMax  priceMod
# 11678  YEOLA(MS)  December   2013     215883       472       1427      1177
# 11679  YEOLA(MS)  December   2014     201077       446       1654      1456
# 11680  YEOLA(MS)  December   2015     223315       609       1446      1126
# 11681  YEOLA(MS)  December   2016     214937       256        753       634
# 11682        NaN       NaN  Total  862952226  636(Avg)  1187(Avg)  962(Avg)

# %%
df_raw.dtypes
# Out:
# market      object
# month       object
# year        object
# quantity     int64
# priceMin    object
# priceMax    object
# priceMod    object
# dtype: object

# %%
df_raw.shape
# Out:
# (11683, 7)

# %%
df_raw.size
# Out:
# 81781

# %% [markdown]
# ### Basic Functions:
#  - Head
#  - Tail
#  - Shape
#  - Size
#  - Access particular column or row
#  - Access particular cell
#  - Change the column name
#
# basically checking out first 5 rows, last 5 rows, column names and data types, rows and columns, total no. of cells i.e. multiplication of rows * columns

# %%
df_raw.market.head
# Out:
# <bound method NDFrame.head of 0        ABOHAR(PB)
# 1        ABOHAR(PB)
# 2        ABOHAR(PB)
# 3        ABOHAR(PB)
# 4        ABOHAR(PB)
# 5        ABOHAR(PB)
# 6        ABOHAR(PB)
# 7        ABOHAR(PB)
# 8        ABOHAR(PB)
# 9        ABOHAR(PB)
# 10       ABOHAR(PB)
# 11       ABOHAR(PB)
# 12       ABOHAR(PB)
# 13       ABOHAR(PB)
# 14       ABOHAR(PB)
# 15       ABOHAR(PB)
# 16       ABOHAR(PB)
# 17       ABOHAR(PB)
# 18       ABOHAR(PB)
# 19       ABOHAR(PB)
# 20       ABOHAR(PB)
# 21       ABOHAR(PB)
# 22       ABOHAR(PB)
# 23       ABOHAR(PB)
# 24       ABOHAR(PB)
# 25       ABOHAR(PB)
# 26       ABOHAR(PB)
# 27       ABOHAR(PB)
# 28       ABOHAR(PB)
# 29       ABOHAR(PB)
#             ...
# 11653     YEOLA(MS)
# 11654     YEOLA(MS)
# 11655     YEOLA(MS)
# 11656     YEOLA(MS)
# 11657     YEOLA(MS)
# 11658     YEOLA(MS)
# 11659     YEOLA(MS)
# 11660     YEOLA(MS)
# 11661     YEOLA(MS)
# 11662     YEOLA(MS)
# 11663     YEOLA(MS)
# 11664     YEOLA(MS)
# 11665     YEOLA(MS)
# ...

# %%
df_raw.market.head()
# Out:
# 0    ABOHAR(PB)
# 1    ABOHAR(PB)
# 2    ABOHAR(PB)
# 3    ABOHAR(PB)
# 4    ABOHAR(PB)
# Name: market, dtype: object

# %%
df_raw.head?

# %%
df_raw['market'].head()
# Out:
# 0    ABOHAR(PB)
# 1    ABOHAR(PB)
# 2    ABOHAR(PB)
# 3    ABOHAR(PB)
# 4    ABOHAR(PB)
# Name: market, dtype: object

# %% [markdown]
# Two ways to access data
# - index based
# - label based

# %%
df_raw.iloc[0,0]
# Out:
# 'ABOHAR(PB)'

# %%
df_raw.loc[0, "market"]
# Out:
# 'ABOHAR(PB)'

# %% [markdown]
# df.columns

# %%
df_raw.columns
# Out:
# Index(['market1', 'month', 'year', 'quantity', 'priceMin', 'priceMax',
#        'priceMod'],
#       dtype='object')

# %%
#df.index

# %%
df_raw.index
# Out:
# RangeIndex(start=0, stop=11683, step=1)

# %%
df_raw.columns
# Out:
# Index(['market1', 'month', 'year', 'quantity', 'priceMin', 'priceMax',
#        'priceMod'],
#       dtype='object')

# %%
df_raw.columns= ['market1', 'month', 'year', 'quantity', 'priceMin', 'priceMax',
       'priceMod']

# %%
df_raw.head()
# Out:
#       market1    month  year  quantity priceMin priceMax priceMod
# 0  ABOHAR(PB)  January  2005      2350      404      493      446
# 1  ABOHAR(PB)  January  2006       900      487      638      563
# 2  ABOHAR(PB)  January  2010       790     1283     1592     1460
# 3  ABOHAR(PB)  January  2011       245     3067     3750     3433
# 4  ABOHAR(PB)  January  2012      1035      523      686      605

# %%
df_raw.month.head()
# Out:
# 0    January
# 1    January
# 2    January
# 3    January
# 4    January
# Name: month, dtype: object

# %%
df_raw.year.head()
# Out:
# 0    2005
# 1    2006
# 2    2010
# 3    2011
# 4    2012
# Name: year, dtype: object

# %%
df_raw[:2] [:2]
# Out:
#       market1    month  year  quantity priceMin priceMax priceMod
# 0  ABOHAR(PB)  January  2005      2350      404      493      446
# 1  ABOHAR(PB)  January  2006       900      487      638      563

# %% [markdown]
# Excercises
# - get the columns - "month and year" and rows - 1& 2
# - get the columns - "month and proceMin and rows 1&5

# %%
#df_raw.loc[1, "market"] -> needs to be in "" as it is a string

# %%
#df_raw.loc[1, month] ->month needs to be in "" as it is a string

# %%
#df_raw.loca[1, "month"]    -> see spelling mistake

# %%
df_raw.loc[1, "month"]
# Out:
# 'January'

# %%
df_raw.loc[1, "year"]
# Out:
# '2006'

# %%
#Excercise 1

col_ex1 = ['month', 'year']
row_ex1 = [1, 2]

# %%
df_raw.loc[row_ex1, col_ex1]
# Out:
#      month  year
# 1  January  2006
# 2  January  2010

# %%
df_raw.iloc[1:3,1:3]
# Out:
#      month  year
# 1  January  2006
# 2  January  2010

# %% [markdown]
# What are we refining in dataframe
# - Remove empty cells
# - Add some new columns
# - Parsing Data
# - Missing Values
# - Quality Checks

# %%
df_raw.tail(1)
# Out:
#       market1 month   year   quantity  priceMin   priceMax  priceMod
# 11682     NaN   NaN  Total  862952226  636(Avg)  1187(Avg)  962(Avg)

# %%
#drop
df_raw.drop(df_raw.tail(1).index)
# Out:
#           market1     month  year  quantity priceMin priceMax priceMod
# 0      ABOHAR(PB)   January  2005      2350      404      493      446
# 1      ABOHAR(PB)   January  2006       900      487      638      563
# 2      ABOHAR(PB)   January  2010       790     1283     1592     1460
# 3      ABOHAR(PB)   January  2011       245     3067     3750     3433
# 4      ABOHAR(PB)   January  2012      1035      523      686      605
# 5      ABOHAR(PB)   January  2013       675     1327     1900     1605
# 6      ABOHAR(PB)   January  2014       440     1025     1481     1256
# 7      ABOHAR(PB)   January  2015      1305     1309     1858     1613
# 8      ABOHAR(PB)   January  2017       200      750     1000      850
# 9      ABOHAR(PB)  February  2005      1400      286      365      324
# 10     ABOHAR(PB)  February  2006      1800      343      411      380
# 11     ABOHAR(PB)  February  2010       555     1143     1460     1322
# ...

# %%
#now it will actually drop, as we are reassigning the dataframe, we are dropping the
#last row as it just contains the total of all columns
df1=df_raw.drop(df_raw.tail(1).index)

# %%
df1.tail()
# Out:
#          market1     month  year  quantity priceMin priceMax priceMod
# 11677  YEOLA(MS)  December  2012    207066      485     1327     1136
# 11678  YEOLA(MS)  December  2013    215883      472     1427     1177
# 11679  YEOLA(MS)  December  2014    201077      446     1654     1456
# 11680  YEOLA(MS)  December  2015    223315      609     1446     1126
# 11681  YEOLA(MS)  December  2016    214937      256      753      634

# %%
df1.dtypes
# Out:
# market1     object
# month       object
# year        object
# quantity     int64
# priceMin    object
# priceMax    object
# priceMod    object
# dtype: object

# %%
#create a date column
df1['date'] =df_raw['month'] + "-" +df_raw["year"]

# %%
df1.head()
# Out:
#       market1    month  year  quantity priceMin priceMax priceMod  \
# 0  ABOHAR(PB)  January  2005      2350      404      493      446
# 1  ABOHAR(PB)  January  2006       900      487      638      563
# 2  ABOHAR(PB)  January  2010       790     1283     1592     1460
# 3  ABOHAR(PB)  January  2011       245     3067     3750     3433
# 4  ABOHAR(PB)  January  2012      1035      523      686      605
#
#            date
# 0  January-2005
# 1  January-2006
# 2  January-2010
# 3  January-2011
# 4  January-2012

# %%
df1.date= pd.to_datetime(df1.date)

# %%
df1.dtypes
# Out:
# market1             object
# month               object
# year                object
# quantity             int64
# priceMin            object
# priceMax            object
# priceMod            object
# date        datetime64[ns]
# dtype: object

# %%
pd.to_datetime('jan-2012')
# Out:
# Timestamp('2012-01-01 00:00:00')

# %%
pd.to_datetime('26-april-1991')
# Out:
# Timestamp('1991-04-26 00:00:00')

# %%
df1.priceMin = pd.to_numeric(df1.priceMin)
df1.priceMax = pd.to_numeric(df1.priceMax)
df1.priceMod = pd.to_numeric(df1.priceMod)

# %%
df1.market1
# Out:
# 0        ABOHAR(PB)
# 1        ABOHAR(PB)
# 2        ABOHAR(PB)
# 3        ABOHAR(PB)
# 4        ABOHAR(PB)
# 5        ABOHAR(PB)
# 6        ABOHAR(PB)
# 7        ABOHAR(PB)
# 8        ABOHAR(PB)
# 9        ABOHAR(PB)
# 10       ABOHAR(PB)
# 11       ABOHAR(PB)
# 12       ABOHAR(PB)
# 13       ABOHAR(PB)
# 14       ABOHAR(PB)
# 15       ABOHAR(PB)
# 16       ABOHAR(PB)
# 17       ABOHAR(PB)
# 18       ABOHAR(PB)
# 19       ABOHAR(PB)
# 20       ABOHAR(PB)
# 21       ABOHAR(PB)
# 22       ABOHAR(PB)
# 23       ABOHAR(PB)
# 24       ABOHAR(PB)
# 25       ABOHAR(PB)
# 26       ABOHAR(PB)
# 27       ABOHAR(PB)
# 28       ABOHAR(PB)
# 29       ABOHAR(PB)
#             ...
# 11652     YEOLA(MS)
# 11653     YEOLA(MS)
# 11654     YEOLA(MS)
# 11655     YEOLA(MS)
# 11656     YEOLA(MS)
# 11657     YEOLA(MS)
# 11658     YEOLA(MS)
# 11659     YEOLA(MS)
# 11660     YEOLA(MS)
# 11661     YEOLA(MS)
# 11662     YEOLA(MS)
# 11663     YEOLA(MS)
# 11664     YEOLA(MS)
# 11665     YEOLA(MS)
# ...

# %%
df1.market1.unique()
# Out:
# array(['ABOHAR(PB)', 'AGRA(UP)', 'AHMEDABAD(GUJ)', 'AHMEDNAGAR(MS)',
#        'AIGINIA MANDIA (OR)', 'AJMER(RAJ)', 'ALIGARH(UP)', 'ALLAHABAD(UP)',
#        'ALWAR(RAJ)', 'AMRITSAR(PB)', 'ANGUL(OR)', 'ASANSOL (WB)',
#        'AURANGABAD(MS)', 'BALLIA(UP)', 'BAMPADA(OR)', 'BANGALORE',
#        'BAREILLY(UP)', 'BARGARH(OR)', 'BELGAUM(KNT)', 'BETNOTI(OR)',
#        'BHATINDA(PB)', 'BHAVNAGAR(GUJ)', 'BHOPAL', 'BHUBNESWER(OR)',
#        'BIHARSHARIF(BHR)', 'BIJAPUR(KNT)', 'BIKANER(RAJ)',
#        'BINNY MILL (KNT)', 'BOMBORI(MS)', 'BOWENPALLY(Telangana)',
#        'BULANDSHAHR', 'BURDWAN(WB)', 'CHAKAN(MS)', 'CHALA (KER)',
#        'CHALLAKERE(KNT)', 'CHANDIGARH', 'CHANDRAPUR-GANJWAD (MS)',
#        'CHANDVAD(MS)', 'CHENNAI', 'CHICKBALLAPUR(KNT)', 'CHOMU(RAJ)',
#        'COIMBATORE(TN) (bellary)', 'COIMBATORE(TN) (podisu)', 'DEESA(GUJ)',
#        'DEHRADOON(UTT)', 'DELHI', 'DELHI (Others)', 'DEORIA(UP)',
#        'DEVALA(MS)', 'DEWAS(MP)', 'DHAVANGERE(KNT)', 'DHULIA(MS)',
# ...

# %% [markdown]
# #  String Manipulation

# %%
df1['market']=df1.market1.str.split('(').str[0]

# %%
df1['state']=df1.market1.str.split('(').str[-1]

# %%
df1.head()
# Out:
#       market1    month  year  quantity  priceMin  priceMax  priceMod  \
# 0  ABOHAR(PB)  January  2005      2350       404       493       446
# 1  ABOHAR(PB)  January  2006       900       487       638       563
# 2  ABOHAR(PB)  January  2010       790      1283      1592      1460
# 3  ABOHAR(PB)  January  2011       245      3067      3750      3433
# 4  ABOHAR(PB)  January  2012      1035       523       686       605
#
#         date  market state
# 0 2005-01-01  ABOHAR   PB)
# 1 2006-01-01  ABOHAR   PB)
# 2 2010-01-01  ABOHAR   PB)
# 3 2011-01-01  ABOHAR   PB)
# 4 2012-01-01  ABOHAR   PB)

# %% [markdown]
# # Extraction & Transform

# %%
df1.dtypes
# Out:
# market1             object
# month               object
# year                object
# quantity             int64
# priceMin             int64
# priceMax             int64
# priceMod             int64
# date        datetime64[ns]
# market              object
# state               object
# dtype: object

# %% [markdown]
# ### Questions
#
# - Which is the biggest market in quantity for Onion
# - Which is the market with highest price
# - What is the trend for price in Bangalore

# %%
df1.size
# Out:
# 116820

# %% [markdown]
# ### filter /subset on condition

# %%
df1.year = pd.to_numeric(df1.year)
df2015=df1[df1.year==2015]
#df1.quantity.max()

# %%
df2015=df1[df1.year==2015]
#df2015.head()

# %%
df2015.groupby(['market1'])

# %%
df2015.groupby(['market1']).sum().quantity.sum()
# Out:
# 75538505

# %%
df1.filter?

# %%
df2015market =(
 df1[df1.year ==2015]
    .groupby(['market1'])
    .quantity
    .sum()
    .sort_values(ascending = False)
    .head(10)
)

# %%
df1.sort_values?

# %%
#wrong
#df1.sort_values(by, axis=0, ascending=False)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# %matplotlib inline

# %%
plt.style.use("ggplot")

# %%
#df2015market.plot(kind="bar")
df2015market.plot(kind="barh")

# %%
#pd._version_   -> mistake we need to double underscores in the beginning and the end

# %%
pd.__version__
# Out:
# '0.20.3'

# %%
mpl.__version__
# Out:
# '2.1.1'

# %%
# !conda update panda -y
# Out:
# PackageNotInstalledError: Package is not installed in prefix.
#   prefix: /Users/jagritij/anaconda3
#   package name: panda

# %%
# !pip install panda
# Out:
# ...
#   Running setup.py bdist_wheel for panda ... done
#   Stored in directory: /Users/jagritij/Library/Caches/pip/wheels/b1/0a/f7/13d736ab670801e9e92f512d2600fcac98a50dabf2bc52035a
# Successfully built panda
# ...

# %%
# !conda update panda -y
# Out:
# PackageNotInstalledError: Package is not installed in prefix.
#   prefix: /Users/jagritij/anaconda3
#   package name: panda

# %%
pd.__version__
# Out:
# '0.20.3'

# %%
#!pip install pdvega    - once downloadedm make it inot hash
# Out:
# ...
#     100% |████████████████████████████████| 61kB 489kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 1.7MB 597kB/s ta 0:00:011
# ...
#   Running setup.py bdist_wheel for pdvega ... done
#   Stored in directory: /Users/jagritij/Library/Caches/pip/wheels/ea/54/44/41f485c587f1bf580be7a5937a59048c307348b12af9586467
#   Running setup.py bdist_wheel for vega3 ... done
#   Stored in directory: /Users/jagritij/Library/Caches/pip/wheels/1a/e9/cf/d2db14d76d79eaaada76ef650f1e4c0e6f0c901be630f29019
# Successfully built pdvega vega3
# ...

# %%
import pdvega

# %%
df2015market.vgplot.bar()
# Out:
# <div class="vega-embed" id="7d31ffd5-6600-457a-9a83-30a1dca6e4a8"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
df1.head()
# Out:
#       market1    month  year  quantity  priceMin  priceMax  priceMod  \
# 0  ABOHAR(PB)  January  2005      2350       404       493       446
# 1  ABOHAR(PB)  January  2006       900       487       638       563
# 2  ABOHAR(PB)  January  2010       790      1283      1592      1460
# 3  ABOHAR(PB)  January  2011       245      3067      3750      3433
# 4  ABOHAR(PB)  January  2012      1035       523       686       605
#
#         date  market state
# 0 2005-01-01  ABOHAR   PB)
# 1 2006-01-01  ABOHAR   PB)
# 2 2010-01-01  ABOHAR   PB)
# 3 2011-01-01  ABOHAR   PB)
# 4 2012-01-01  ABOHAR   PB)

# %% [markdown]
# ### Plot the price in bangalore

# %%
pd.unique(df1.market1)
# Out:
# array(['ABOHAR(PB)', 'AGRA(UP)', 'AHMEDABAD(GUJ)', 'AHMEDNAGAR(MS)',
#        'AIGINIA MANDIA (OR)', 'AJMER(RAJ)', 'ALIGARH(UP)', 'ALLAHABAD(UP)',
#        'ALWAR(RAJ)', 'AMRITSAR(PB)', 'ANGUL(OR)', 'ASANSOL (WB)',
#        'AURANGABAD(MS)', 'BALLIA(UP)', 'BAMPADA(OR)', 'BANGALORE',
#        'BAREILLY(UP)', 'BARGARH(OR)', 'BELGAUM(KNT)', 'BETNOTI(OR)',
#        'BHATINDA(PB)', 'BHAVNAGAR(GUJ)', 'BHOPAL', 'BHUBNESWER(OR)',
#        'BIHARSHARIF(BHR)', 'BIJAPUR(KNT)', 'BIKANER(RAJ)',
#        'BINNY MILL (KNT)', 'BOMBORI(MS)', 'BOWENPALLY(Telangana)',
#        'BULANDSHAHR', 'BURDWAN(WB)', 'CHAKAN(MS)', 'CHALA (KER)',
#        'CHALLAKERE(KNT)', 'CHANDIGARH', 'CHANDRAPUR-GANJWAD (MS)',
#        'CHANDVAD(MS)', 'CHENNAI', 'CHICKBALLAPUR(KNT)', 'CHOMU(RAJ)',
#        'COIMBATORE(TN) (bellary)', 'COIMBATORE(TN) (podisu)', 'DEESA(GUJ)',
#        'DEHRADOON(UTT)', 'DELHI', 'DELHI (Others)', 'DEORIA(UP)',
#        'DEVALA(MS)', 'DEWAS(MP)', 'DHAVANGERE(KNT)', 'DHULIA(MS)',
# ...

# %%
df1[df1.market1=="BANGALORE"]
# Out:
#         market1     month  year  quantity  priceMin  priceMax  priceMod  \
# 847   BANGALORE   January  2004    227832       916      1066       991
# 848   BANGALORE   January  2005    335679       470       597       522
# 849   BANGALORE   January  2006    412185       286       617       537
# 850   BANGALORE   January  2007    268268       586      1167       942
# 851   BANGALORE   January  2008    393806       174       671       472
# 852   BANGALORE   January  2009    374380       848      1554      1328
# 853   BANGALORE   January  2010    423649       502      1837      1267
# 854   BANGALORE   January  2011    375695      2029      3167      2731
# 855   BANGALORE   January  2012    531906       161       736       583
# 856   BANGALORE   January  2013    426367       857      1830      1551
# 857   BANGALORE   January  2014    606710       404      1296      1094
# 858   BANGALORE   January  2015    583681       313      1967      1602
# ...

# %%
df1[df1.market1=="BANGALORE"].plot(x="date", y= ["priceMod", "priceMin", "priceMax"])

# %% [markdown]
# # Modelling

# %%
dfBang = df1[df1.market == "BANGALORE"]

# %%
dfBang.plot(kind="scatter", x="quantity", y="priceMod")

# %%
dfBang.head()
# Out:
#        market1    month  year  quantity  priceMin  priceMax  priceMod  \
# 847  BANGALORE  January  2004    227832       916      1066       991
# 848  BANGALORE  January  2005    335679       470       597       522
# 849  BANGALORE  January  2006    412185       286       617       537
# 850  BANGALORE  January  2007    268268       586      1167       942
# 851  BANGALORE  January  2008    393806       174       671       472
#
#           date     market      state
# 847 2004-01-01  BANGALORE  BANGALORE
# 848 2005-01-01  BANGALORE  BANGALORE
# 849 2006-01-01  BANGALORE  BANGALORE
# 850 2007-01-01  BANGALORE  BANGALORE
# 851 2008-01-01  BANGALORE  BANGALORE

# %%
y=dfBang["priceMod"]

# %%
print (y)
# Out:
# 847      991
# 848      522
# 849      537
# 850      942
# 851      472
# 852     1328
# 853     1267
# 854     2731
# 855      583
# 856     1551
# 857     1094
# 858     1602
# 859     1448
# 860      824
# 861      793
# 862      485
# 863      405
# 864     1122
# 865      461
# 866     1250
# 867     1011
# 868     1186
# 869      524
# 870     1537
# 871      797
# 872     1662
# 873     1027
# 874      556
# 875      398
# 876      353
#         ...
# 974     3430
# 975     1546
# 976     2215
# 977      680
# 978      494
# 979      950
# 980      416
# 981      811
# 982      926
# 983     1444
# 984     1718
# 985     1048
# 986     1468
# 987     2709
# 988     1403
# 989     1618
# 990      881
# 991      476
# 992      673
# 993      391
# 994      642
# 995     1007
# 996     1491
# 997     2802
# 998      754
# 999     1524
# 1000    1504
# 1001    1386
# 1002    1343
# 1003     875
# Name: priceMod, Length: 157, dtype: int64

# %%
y=dfBang[["priceMod"]]

# %%
print(y)
# Out:
#       priceMod
# 847        991
# 848        522
# 849        537
# 850        942
# 851        472
# 852       1328
# 853       1267
# 854       2731
# 855        583
# 856       1551
# 857       1094
# 858       1602
# 859       1448
# 860        824
# 861        793
# 862        485
# 863        405
# 864       1122
# 865        461
# 866       1250
# 867       1011
# 868       1186
# 869        524
# 870       1537
# 871        797
# 872       1662
# 873       1027
# 874        556
# 875        398
# 876        353
# ...        ...
# 974       3430
# 975       1546
# 976       2215
# 977        680
# 978        494
# 979        950
# 980        416
# 981        811
# 982        926
# 983       1444
# 984       1718
# 985       1048
# 986       1468
# 987       2709
# 988       1403
# 989       1618
# 990        881
# 991        476
# 992        673
# 993        391
# 994        642
# 995       1007
# 996       1491
# 997       2802
# 998        754
# 999       1524
# ...

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
type(dfBang["priceMod"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Step1  Create Target and Features

# %%
y=dfBang[["priceMod"]]

# %%
X=dfBang[["quantity"]]

# %% [markdown]
# ### Step 2 - import sklearn

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Step 3 - Instantiate the model

# %%
model_1=LinearRegression()

# %%
model_1
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y
# Out:
#       priceMod
# 847        991
# 848        522
# 849        537
# 850        942
# 851        472
# 852       1328
# 853       1267
# 854       2731
# 855        583
# 856       1551
# 857       1094
# 858       1602
# 859       1448
# 860        824
# 861        793
# 862        485
# 863        405
# 864       1122
# 865        461
# 866       1250
# 867       1011
# 868       1186
# 869        524
# 870       1537
# 871        797
# 872       1662
# 873       1027
# 874        556
# 875        398
# 876        353
# ...        ...
# 974       3430
# 975       1546
# 976       2215
# 977        680
# 978        494
# 979        950
# 980        416
# 981        811
# 982        926
# 983       1444
# 984       1718
# 985       1048
# 986       1468
# 987       2709
# 988       1403
# 989       1618
# 990        881
# 991        476
# 992        673
# 993        391
# 994        642
# 995       1007
# 996       1491
# 997       2802
# 998        754
# 999       1524
# ...

# %%
X
# Out:
#       quantity
# 847     227832
# 848     335679
# 849     412185
# 850     268268
# 851     393806
# 852     374380
# 853     423649
# 854     375695
# 855     531906
# 856     426367
# 857     606710
# 858     583681
# 859     507223
# 860     363991
# 861     225133
# 862     279047
# 863     317020
# 864     240681
# 865     268281
# 866     296311
# 867     316685
# 868     367503
# 869     363037
# 870     351372
# 871     522132
# 872     405716
# 873     465640
# 874     221952
# 875     269609
# 876     337968
# ...        ...
# 974    1639032
# 975    1412686
# 976    1612160
# 977    1620273
# 978     724140
# 979     775223
# 980    1016812
# 981     940095
# 982     782498
# 983     720428
# 984     661830
# 985     970352
# 986     903459
# 987     710266
# 988    1235389
# 989    1071872
# 990    1974018
# 991     380379
# 992     684732
# 993     659518
# 994     721043
# 995     523198
# 996     550062
# 997     662016
# 998     706820
# 999     515118
# ...

# %% [markdown]
# ### Step 4 - Fit the Model

# %%
model_1.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# ### Step 5 -  Intercept and Coefficient

# %%
model_1.coef_, model_1.intercept_
# Out:
# (array([[ 0.00068406]]), array([ 657.34274395]))

# %% [markdown]
#  ### Step 6 - Predict

# %%
model_1.predict(1000)
# Out:
# array([[ 658.02680466]])

# %% [markdown]
# ### Plot the prediction

# %%
y_predict = model_1.predict(X)

# %%
dfBang.plot(kind="scatter", x="quantity", y="priceMod")
plt.plot(X, y_predict)

# %%
??model_1.fit

# %% [markdown]
# Prediction using 1 more model, add 1 more column
