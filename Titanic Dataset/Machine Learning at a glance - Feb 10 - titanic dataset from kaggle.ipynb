# %% [markdown]
# Learning Markdown
#
# # Heading
# ## Subheading 1
# ### Subheading 2
# Text:
# This is my first jupyter notebook
# - List item: I will write Machine learning models here
# - List item: I will discuss the differences between AI, ML and DL, NN
# - List item: When to apply ML and when to apply DL
#
# Other Keyboard Shortcuts:
#
# Press esc to change the color from blue to green of the cell and then press M for Markdown.
# Delete a cell, press delete twice or use the Cut option at the top
# Add Cell below - press B
# Add Cell above - press A

# %% [markdown]
# # AI
# AI is the bigger umbrella and Machine Learning is subset of it and deep learning is a subset of Machine learning. Deep Learning techniques uses Neural Networks and hence the terms Deep Learning and Neural Networks are used synchronously.
#
#
# ## Machine Learning
# Machine Learning is nothing but making the Machine to learn
# So basically we aren't writing any static code for it.
# For e.g. Self- Driving Car, so everything or every scenario can't be coded for the car, just imagine if we have to code that it would be some hundred + if elses.

# %% [markdown]
# Where is Machine Learning being used these days?
# - Spam Detector in Gmail - you feed the data in your gmail telling what is spam for you?
# - Capctha - how is it able to match what we write in text box and what characters are there in the image
# - Self Driving car - uses more of Deep Learning though
# - Facebook image tagging, or iphone's image tagging - how can it recognize who your friends are, because once upon a time you only tagged your friend and over a period of time and a huge database it has built
# - Given a photo [dog or a cat], how can your model identify if it's a dog vs cat?
# - Recommendation system on Ecommerce sites - Amazon, Flipkart, etc. when it says "people also bought this" for e.g. when you are purchasing a phone it will also show you the Phone covers
# - Amazon's fully automatic Go store in Seattle
# - Quick reply options on the gmail and linkedin - it understands the context of the email or chat and gives recommended responses to choose from

# %% [markdown]
# ### ML vs DL
#
# - One of the important differences is when the dataset in tabular format like csv, HDFS, etc. then we use ML. Model learns just functions
# - If the dataset is image, voice, video then we use DL. In DL the model learns Features and Functions. Mostly uses Gradient Descent with Back Propagation

# %% [markdown]
# ## Some Popular datasets/ Datasets I came across
# - Iris dataset - given dataset of Petals and sepals, given a new sepal or petal, identify which one is it
# - MNIST database
# - Onion Price dataset
# - Loan Defaul dataset

# %% [markdown]
# ## Some basic Python to get started
# - cs231n.github.io/python-numpy-tutorial/ is a good place to start
# - http://hackerrank.com/domains/python/py-introduction
# - https://jakevdp.github.io/PythonDataScienceHandbook/
#
#
# ### Why Python for ML?
# It is usually said,
# use R - smallto medium dataset
# Python - medium to large dataset
# Scala - for very large dataset

# %% [markdown]
# ### Where to get the datasets for practice and participate in competitions:
#
# https://www.kaggle.com/

# %% [markdown]
# ### What is Numpy, Pandas, Matplotlib, Scipy and Sklearn in Python
# Python itself is a slow in processing
# All these are python libraries which provides some extra functionality
# - Numpy: used for mathematical calculations [processing multi dimensional arrays, vector addition, etc]
# - Pandas: for data prpeocessing, cleansing, data structures
# - Matplotlib: Library which is used to visualize the data, as in draw graphs and diagrams
# - SciPy: is a collection of mathematical algorithms and convenience functions built on the Numpy extension of Python.
#
# https://www.quora.com/What-is-the-relationship-among-NumPy-SciPy-Pandas-and-Scikit-learn-and-when-should-I-use-each-one-of-them
#
# To check the performance of Pure Python vs Numpy and Pandas
# http://machinelearningexp.com/data-science-performance-of-python-vs-pandas-vs-numpy/

# %% [markdown]
# ### Solving a basic ML Problem: https://www.kaggle.com/c/titanic/data
#  Analysis of what sorts of people were likely to survive.

# %% [markdown]
# Overview
# The data has been split into two groups:
#
# training set (train.csv)
# test set (test.csv)
# The training set should be used to build your machine learning models. For the training set, we provide the outcome (also known as the “ground truth”) for each passenger. Your model will be based on “features” like passengers’ gender and class. You can also use feature engineering to create new features.
#
# The test set should be used to see how well your model performs on unseen data. For the test set, we do not provide the ground truth for each passenger. It is your job to predict these outcomes. For each passenger in the test set, use the model you trained to predict whether or not they survived the sinking of the Titanic.
#
# We also include gender_submission.csv, a set of predictions that assume all and only female passengers survive, as an example of what a submission file should look like.
#
# Data Dictionary
# Variable	Definition	Key
# survival	Survival	0 = No, 1 = Yes
# pclass	Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd
# sex	Sex
# Age	Age in years
# sibsp	# of siblings / spouses aboard the Titanic
# parch	# of parents / children aboard the Titanic
# ticket	Ticket number
# fare	Passenger fare
# cabin	Cabin number
# embarked	Port of Embarkation	C = Cherbourg, Q = Queenstown, S = Southampton
# Variable Notes
# pclass: A proxy for socio-economic status (SES)
# 1st = Upper
# 2nd = Middle
# 3rd = Lower
#
# age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# sibsp: The dataset defines family relations in this way...
# Sibling = brother, sister, stepbrother, stepsister
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# parch: The dataset defines family relations in this way...
# Parent = mother, father
# Child = daughter, son, stepdaughter, stepson
# Some children travelled only with a nanny, therefore parch=0 for them.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")

# %%
# !pwd
# Out:
# /Users/jagritij/art-data-science

# %%
df=pd.read_csv("notebook/Titanic Dataset/train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.shape
# Out:
# (891, 12)

# %%
df.size
# Out:
# 10692

# %%
df.Pclass.head()
# Out:
# 0    3
# 1    1
# 2    3
# 3    1
# 4    3
# Name: Pclass, dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
columns1 = ["PassengerId", "Pclass", "Sex", "Age", "Fare"]

# %%
#df.columns = df.columns [:-1,columns1]

# %%
df.plot

# %%
df.plot(kind="barh", x="PassengerId", y="Survived")

# %%
from sklearn import preprocessing

# %%
df1=df.copy()

# %%
#df.Sex = pd.to_numeric(df.Sex)

# %%
#instantiate a label encoder
le = preprocessing.LabelEncoder()

# %%
df1.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
#fit the label encoder
le.fit(df['Sex'])
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['female', 'male'], dtype=object)

# %%
df1.Sex = le.fit(df['Sex'])

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name             Sex   Age  \
# 0                            Braund, Mr. Owen Harris  LabelEncoder()  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  LabelEncoder()  38.0
# 2                             Heikkinen, Miss. Laina  LabelEncoder()  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  LabelEncoder()  35.0
# 4                           Allen, Mr. William Henry  LabelEncoder()  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      1      0            113803  53.1000  C123        S
# ...

# %%
#Transform the Credit History
df1['Sex'] = le.transform(df['Sex'])

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
type(df.Sex)
# Out:
# pandas.core.series.Series

# %%
le1 = preprocessing.LabelEncoder()

# %%
df1.Embarked.unique()
#le1.classes_
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
#le1.fit(df['Embarked'])

# %%
#df1['Embarked'] = le1.transform([df['Embarked']])

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %% [markdown]
# ### Model

# %%
y = df1['Survived']

# %%
#y

# %%
X = df1[['PassengerId', 'Pclass', 'Sex', 'Age']]

# %%
X
# Out:
#      PassengerId  Pclass  Sex   Age
# 0              1       3    1  22.0
# 1              2       1    0  38.0
# 2              3       3    0  26.0
# 3              4       1    0  35.0
# 4              5       3    1  35.0
# 5              6       3    1   NaN
# 6              7       1    1  54.0
# 7              8       3    1   2.0
# 8              9       3    0  27.0
# 9             10       2    0  14.0
# 10            11       3    0   4.0
# 11            12       1    0  58.0
# 12            13       3    1  20.0
# 13            14       3    1  39.0
# 14            15       3    0  14.0
# 15            16       2    0  55.0
# 16            17       3    1   2.0
# 17            18       2    1   NaN
# 18            19       3    0  31.0
# 19            20       3    0   NaN
# 20            21       2    1  35.0
# 21            22       2    1  34.0
# 22            23       3    0  15.0
# 23            24       1    1  28.0
# 24            25       3    0   8.0
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-12b5b6bd5106> in <module>()
# ----> 1 clf.fit(X,y)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     117             y = check_array(y, ensure_2d=False, dtype=None)
#     118             if issparse(X):
#
# ...

# %%
df1.isnull().head()
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
# 3        False     False   False  False  False  False  False  False   False
# 4        False     False   False  False  False  False  False  False   False
#
#     Fare  Cabin  Embarked
# 0  False   True     False
# 1  False  False     False
# 2  False   True     False
# 3  False  False     False
# 4  False   True     False

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df1.Age.fillna(df1.Age.median(), inplace=True)

# %%
#df1.Age.isnan(df1.Age.median(), inplace=True)

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#X.isnull().sum

# %%
clf.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-12b5b6bd5106> in <module>()
# ----> 1 clf.fit(X,y)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     117             y = check_array(y, ensure_2d=False, dtype=None)
#     118             if issparse(X):
#
# ...

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-cd4fa705ad81> in <module>()
# ----> 1 X.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
#X[np.isnan('Age')] = np.median(X[~np.isnan(Age)])

# %%
X.Age = pd.to_numeric(X.Age)
# Out:
# /Users/jagritij/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
clf.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-12b5b6bd5106> in <module>()
# ----> 1 clf.fit(X,y)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     117             y = check_array(y, ensure_2d=False, dtype=None)
#     118             if issparse(X):
#
# ...

# %%
X.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Sex              int64
# Age            float64
# dtype: object

# %%
X.Age = pd.to_int64(X.Age)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-d59fbfdea5d4> in <module>()
# ----> 1 X.Age = pd.to_int64(X.Age)
#
# AttributeError: module 'pandas' has no attribute 'to_int64'

# %%
X['Age'].apply(pd.to_numeric, errors='coerce')
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17      NaN
# 18     31.0
# 19      NaN
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26      NaN
# 27     19.0
# 28      NaN
# 29      NaN
#        ...
# 861    21.0
# 862    48.0
# 863     NaN
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868     NaN
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     NaN
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
X.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Sex              int64
# Age            float64
# dtype: object

# %%
X['Age'] = X['Age'].astype(np.int64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-893fd85f8706> in <module>()
# ----> 1 X['Age'] = X['Age'].astype(np.int64)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ...

# %%
X.Age.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19      True
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26      True
# 27     False
# 28      True
# 29      True
#        ...
# 861    False
# 862    False
# 863     True
# 864    False
# 865    False
# 866    False
# 867    False
# 868     True
# 869    False
# 870    False
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# 876    False
# 877    False
# 878     True
# 879    False
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
X['Age']=X.Age.dropna()
# Out:
# /Users/jagritij/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X.Age.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19      True
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26      True
# 27     False
# 28      True
# 29      True
#        ...
# 861    False
# 862    False
# 863     True
# 864    False
# 865    False
# 866    False
# 867    False
# 868     True
# 869    False
# 870    False
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# 876    False
# 877    False
# 878     True
# 879    False
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool
